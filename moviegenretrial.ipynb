# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/train_data.txt",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
df
# Out:
# <ipython-input-1-4c84890dd904>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("/content/drive/MyDrive/train_data.txt",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
#           ID                                         TITLE          GENRE  \
# 0          1                 Oscar et la dame rose (2009)          drama
# 1          2                                 Cupid (1997)       thriller
# 2          3             Young, Wild and Wonderful (1980)          adult
# 3          4                        The Secret Sin (1915)          drama
# 4          5                       The Unrecovered (2007)          drama
# ...      ...                                           ...            ...
# 54209  54210                              "Bonino" (1953)         comedy
# ...

# %%
df.describe()
# Out:
#                  ID
# count  54214.000000
# mean   27107.500000
# std    15650.378084
# min        1.000000
# 25%    13554.250000
# 50%    27107.500000
# 75%    40660.750000
# max    54214.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54214 entries, 0 to 54213
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           54214 non-null  int64
#  1   TITLE        54214 non-null  object
#  2   GENRE        54214 non-null  object
#  3   DESCRIPTION  54214 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ MB

# %%
import matplotlib.pyplot as plt
# Get the number of movies in each genre
n_movie_per_genre = df['GENRE'].value_counts().sort_values(ascending=False)

# Configure the plot
plt.bar(n_movie_per_genre.index, n_movie_per_genre.values)
plt.xlabel("Movie Genre")
plt.ylabel("Number of Movies")
plt.title("Number of Movies by Genre in the Dataset")
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/test_data.txt",sep=':::', names=['ID', 'TITLE', 'DESCRIPTION'])
data
# Out:
# <ipython-input-5-d9fb8344ca4a>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("/content/drive/MyDrive/test_data.txt",sep=':::', names=['ID', 'TITLE', 'DESCRIPTION'])
#           ID                             TITLE  \
# 0          1             Edgar's Lunch (1998)
# 1          2         La guerra de papá (1977)
# 2          3      Off the Beaten Track (2010)
# 3          4           Meu Amigo Hindu (2015)
# 4          5                Er nu zhai (1955)
# ...      ...                               ...
# 54195  54196   "Tales of Light & Dark" (2013)
# 54196  54197      Der letzte Mohikaner (1965)
# 54197  54198              Oliver Twink (2007)
# 54198  54199                Slipstream (1973)
# 54199  54200        Curitiba Zero Grau (2010)
#
# ...

# %%
import pandas as pd
test= pd.read_csv("/content/drive/MyDrive/test_data_solution.txt",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
test
# Out:
# <ipython-input-6-b6c3e40a9e12>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test= pd.read_csv("/content/drive/MyDrive/test_data_solution.txt",sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
#           ID                             TITLE          GENRE  \
# 0          1             Edgar's Lunch (1998)       thriller
# 1          2         La guerra de papá (1977)         comedy
# 2          3      Off the Beaten Track (2010)    documentary
# 3          4           Meu Amigo Hindu (2015)          drama
# 4          5                Er nu zhai (1955)          drama
# ...      ...                               ...            ...
# 54195  54196   "Tales of Light & Dark" (2013)         horror
# 54196  54197      Der letzte Mohikaner (1965)        western
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
df['DESCRIPTION'].fillna("", inplace=True)
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['DESCRIPTION'], df['GENRE'], test_size=0.2, random_state=42)

# Feature extraction using TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000)  # Adjust max_features as needed
X_train_features = vectorizer.fit_transform(X_train)
X_test_features = vectorizer.transform(X_test)

# Train the linear SVM model
clf = LinearSVC(random_state=42)
clf.fit(X_train_features, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test_features)

# Evaluate model performance (accuracy in this case)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# Model Accuracy: 0.5495

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

def evaluate_model(data, model, vectorizer):
  """
  Evaluates the model's accuracy on a new dataset.

  Args:
      data: A pandas DataFrame containing columns for "DESCRIPTION" and "GENRE".
      model: The trained LinearSVC model.
      vectorizer: The fitted TfidfVectorizer object.

  Returns:
      The accuracy score (percentage of correctly predicted genres) as a float.
  """
  test['DESCRIPTION'].fillna("", inplace=True)
  # Split the new data into features (descriptions) and target labels (genres)
  X_new = test["DESCRIPTION"]
  y_new = test["GENRE"]

  # Transform the descriptions into TF-IDF vectors
  X_new_features = vectorizer.transform(X_new)

  # Make predictions on the new data
  y_pred = model.predict(X_new_features)

  # Calculate accuracy
  accuracy = accuracy_score(y_new, y_pred)

  return accuracy

# (Rest of your code for training the model remains the same)

# Example usage after training the model (clf) and vectorizer
accuracy = evaluate_model(data, clf, vectorizer)
print(f"Model Accuracy on new data: {accuracy:.4f}")
# Out:
# Model Accuracy on new data: 0.5423

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                precision    recall  f1-score   support
#
#       action        0.34      0.16      0.22       263
#        adult        0.54      0.34      0.42       112
#    adventure        0.33      0.09      0.15       139
#    animation        0.27      0.07      0.11       104
#    biography        0.00      0.00      0.00        61
# ...

# %%
from sklearn.linear_model import LogisticRegression
from joblib import dump  # Import dump function from joblib

# Assuming you have your trained Logistic Regression model in a variable named 'clf'

# Save the model to a file (replace 'model.joblib' with your desired filename)
dump(clf, 'model.joblib')
# Out:
# ['model.joblib']

# %%
dump(vectorizer, 'vectorizer.joblib')
# Out:
# ['vectorizer.joblib']

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

def predict_genre(text, model, vectorizer):
  new_text_features = vectorizer.transform([text])

  # Predict the genre using the trained model
  predicted_genre = model.predict(new_text_features)[0]

  return predicted_genre

# (Rest of your code for training the model remains the same)

# Example usage after training the model (clf) and vectorizer
user_text = "A group of teenagers discover a mysterious object in the woods, leading to strange occurrences and a fight for survival."
predicted_genre = predict_genre(user_text, clf, vectorizer)
print(f"Predicted genre for the description: {predicted_genre}")
# Out:
# Predicted genre for the description:  horror

# %%
# Example usage after training the model (clf) and vectorizer
user_text = "When big business meets big charity, the partnership can be very profitable for both. At the same time this modern-day alliance presents interesting ethical questions about the nature of corporate altruism. Philanthropy Inc. tells the story of this new phenomenon using three case studies involving three of the world's largest corporations and three of the world's largest charities. Each story is an example of how the partnership of business and charity can work, and sometimes not work. Philanthropy, Inc., explores the ethical questions by taking them to the people who know this issue best. We speak to the leaders at the forefront of the movement and examine high profile case studies involving some of North America's corporate giants like Coca-Cola, Wal-Mart and General Mills."
predicted_genre = predict_genre(user_text, clf, vectorizer)
print(f"Predicted genre for the description: {predicted_genre}")
# Out:
# Predicted genre for the description:  documentary

# %%
# Example usage after training the model (clf) and vectorizer
user_text = "Abbey is seen a rare 1991 performance at the Promenade Theater in New York. She is at once beautiful, insightful and at the top of her musical gifts. The appearance represents the beginning of a great comeback that ha"
predicted_genre = predict_genre(user_text, clf, vectorizer)
print(f"Predicted genre for the description: {predicted_genre}")
# Out:
# Predicted genre for the description:  music
